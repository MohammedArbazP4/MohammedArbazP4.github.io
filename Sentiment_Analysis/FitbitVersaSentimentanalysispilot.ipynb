# %% [markdown]
# <a href="https://colab.research.google.com/github/MohammedArbazP4/MohammedArbazP4.github.io/blob/master/FitbitVersaSentimentanalysispilot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install tweepy
# !pip install vaderSentiment

# %%
import tweepy
import pandas as pd 
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
#My twitter API Authentication Variables 
consumer_key = 'qYMKnOPqu5r06HXTCQVa4X1c0'
consumer_secret = 'nkHDPbtUCnon6OQxhy25AuOkFORgOyabhVsBDQ2KIdpJSbbPlB'
access_token='994566855514828800-4fyi2bqOfcqNfPSO8CktOq74Mqo9HyW'
access_token_secret = 'fj3TaXVnBHhq6J6vquAx1DVY6XtxZ0uN07slXdKyDnxAp'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

tweets = api.search('Fitbit Versa', count=200)


data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

display(data.head(10))


print(tweets[0].created_at)
# Out:
#                                               Tweets
# 0  @FitbitUK think my Fitbit Versa band is irrita...
# 1  Win a Fitbit Versa ($199)!  \n\n#free #win #sw...
# 2                 Alguien tiene el fitbit versa? Sos
# 3  @FitbitSupport hi there, I need help badly on ...
# 4  My Fitbit Charge 2 was really accurate when it...
# 5  Fitbit Versa Bands Stainless Steel Bracelet St...
# 6  Just treated myself to a FitBit Versa. I never...
# 7  @TheMrsZilla What do you want it to do for you...
# 8  23mm Leather Watch Band Replacement For Fitbit...
# 9  RT @TechPillsShow: انطباعات ساعات Fitbit الريا...
# 2019-02-12 17:36:55

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
sid = SentimentIntensityAnalyzer()

listy= []

for index, row in data.iterrows():
  ss=sid.polarity_scores(row["Tweets"])
  listy.append(ss)
  
se = pd.Series(listy)
data['polarity'] = se.values

display(data.head(100))
# Out:
#                                                Tweets  \
# 0   @FitbitUK think my Fitbit Versa band is irrita...
# 1   Win a Fitbit Versa ($199)!  \n\n#free #win #sw...
# 2                  Alguien tiene el fitbit versa? Sos
# 3   @FitbitSupport hi there, I need help badly on ...
# 4   My Fitbit Charge 2 was really accurate when it...
# 5   Fitbit Versa Bands Stainless Steel Bracelet St...
# 6   Just treated myself to a FitBit Versa. I never...
# 7   @TheMrsZilla What do you want it to do for you...
# 8   23mm Leather Watch Band Replacement For Fitbit...
# 9   RT @TechPillsShow: انطباعات ساعات Fitbit الريا...
# 10  انطباعات ساعات Fitbit الرياضية\n Versa &amp; I...
# 11  RT @ttmmaftertime: TTMM for Fitbit Versa for A...
# 12  22.5mm Luxury Stainless Steel Watch Band For F...
# 13  RT @tekniikkaluola: Pitkästä aikaa "puettavaa"...
# 14  Pitkästä aikaa "puettavaa" älyteknologiaa kana...
# 15  @AMATUALLAH1231 Apple Watch or fitbit Versa. L...
# ...
